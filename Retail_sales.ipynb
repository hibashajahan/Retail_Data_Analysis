# %%
#import libraries
# !pip install kaggle
import kaggle
# !kaggle datasets download ankitbansal06/retail-orders -f orders.csv --force
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/ankitbansal06/retail-orders
# License(s): CC0-1.0
# ...
#   0%|          | 0.00/200k [00:00<?, ?B/s]
# 100%|##########| 200k/200k [00:00<00:00, 4.62MB/s]

# %%
#extract file from zip file
import zipfile
zip_ref=zipfile.ZipFile('orders.csv.zip')
zip_ref.extractall() #extract file to dir
zip_ref.close() # close file

# %%
#read data from the file and handle null values
import pandas as pd
df=pd.read_csv('orders.csv',na_values=['Not Available', 'unknown'])
df.head(20)
# Out:
#     Order Id  Order Date       Ship Mode      Segment  ... cost price List Price Quantity  Discount Percent
# 0          1  2023-03-01    Second Class     Consumer  ...        240        260        2                 2
# 1          2  2023-08-15    Second Class     Consumer  ...        600        730        3                 3
# 2          3  2023-01-10    Second Class    Corporate  ...         10         10        2                 5
# 3          4  2022-06-18  Standard Class     Consumer  ...        780        960        5                 2
# 4          5  2022-07-13  Standard Class     Consumer  ...         20         20        2                 5
# 5          6  2022-03-13             NaN     Consumer  ...         50         50        7                 3
# 6          7  2022-12-28  Standard Class     Consumer  ...         10         10        4                 3
# 7          8  2022-01-25  Standard Class     Consumer  ...        860        910        6                 5
# ...

# %%
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', nan, 'First Class', 'Same Day'],
#       dtype=object)

# %%
#rename column names. convert to lowercase and replace space with underscore
#df.columns=df.columns.str.lower()
#df.columns=df.columns.str.replace(' ','_')
df.head(5)
# Out:
#    order_id  order_date       ship_mode    segment  ... cost_price list_price quantity  discount_percent
# 0         1  2023-03-01    Second Class   Consumer  ...        240        260        2                 2
# 1         2  2023-08-15    Second Class   Consumer  ...        600        730        3                 3
# 2         3  2023-01-10    Second Class  Corporate  ...         10         10        2                 5
# 3         4  2022-06-18  Standard Class   Consumer  ...        780        960        5                 2
# 4         5  2022-07-13  Standard Class   Consumer  ...         20         20        2                 5
#
# [5 rows x 16 columns]

# %%
#new columns- discount, sale price, and profit
#df['discount']=df['list_price']*df['discount_percent']*.01
#df['sale_price']=df['list_price']-df['discount']
#df['profit']=df['sale_price']-df['cost_price']
df
# Out:
#       order_id  order_date       ship_mode    segment  ... discount_percent discount sale_price  profit
# 0            1  2023-03-01    Second Class   Consumer  ...                2      5.2      254.8    14.8
# 1            2  2023-08-15    Second Class   Consumer  ...                3     21.9      708.1   108.1
# 2            3  2023-01-10    Second Class  Corporate  ...                5      0.5        9.5    -0.5
# 3            4  2022-06-18  Standard Class   Consumer  ...                2     19.2      940.8   160.8
# 4            5  2022-07-13  Standard Class   Consumer  ...                5      1.0       19.0    -1.0
# ...        ...         ...             ...        ...  ...              ...      ...        ...     ...
# 9989      9990  2023-02-18    Second Class   Consumer  ...                4      1.2       28.8    -1.2
# 9990      9991  2023-03-17  Standard Class   Consumer  ...                4      3.6       86.4    16.4
# ...

# %%
#convert order date from object data type to datetime
#df.dtypes
pd.to_datetime(df['order_date'], format="%Y-%m-%d")
# Out:
# 0      2023-03-01
# 1      2023-08-15
# 2      2023-01-10
# 3      2022-06-18
# 4      2022-07-13
#           ...
# 9989   2023-02-18
# 9990   2023-03-17
# 9991   2022-08-07
# 9992   2022-11-19
# 9993   2022-07-17
# Name: order_date, Length: 9994, dtype: datetime64[ns]

# %%
#drop unnecessary columns (cost price, list price, discount percent)
df.drop(columns=['list_price','cost_price','discount_percent'], inplace=True)

# %%
#load data into SQL server using replace option
import sqlalchemy as sal
import pyodbc

# Correct connection string with appropriate driver
connection_string = (
    'mssql+pyodbc://DESKTOP-DEJ6OJK\\SQLEXPRESS/master?'
    'driver=ODBC+Driver+17+for+SQL+Server'
)

# Create an engine instance
engine = sal.create_engine(connection_string)

# Establish a connection
conn = engine.connect()

# Verify connection
print("Connection successful!")
# Out:
# Connection successful!

# %%
#load the data into sql server using append option
df.to_sql('df_orders',con=conn, index=False, if_exists='append')
# Out:
# 38

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_mode', 'segment', 'country', 'city',
#        'state', 'postal_code', 'region', 'category', 'sub_category',
#        'product_id', 'quantity', 'discount', 'sale_price', 'profit'],
#       dtype='object')
